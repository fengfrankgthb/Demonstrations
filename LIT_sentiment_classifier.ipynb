# %% [markdown]
# <a href="https://colab.research.google.com/github/fengfrankgthb/Demonstrations/blob/main/LIT_sentiment_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using the Learning Interpretability Tool in Notebooks
#
# This notebook shows use of the [Learning Interpretability Tool](https://pair-code.github.io/lit) on a binary classifier for labelling statement sentiment (0 for negative, 1 for positive).
#
# The LitWidget object constructor takes a dict mapping model names to model objects, and a dict mapping dataset names to dataset objects. Those will be the datasets and models displayed in LIT. Running the constructor will cause the LIT server to be started in the background, loading the models and datasets and enabling the UI to be served.
#
# Render the LIT UI in an output cell by calling the `render` method on the LitWidget object. The LIT UI can be rendered multiple times in separate cells if desired. The widget also contains a `stop` method to shut down the LIT server.
#
# Copyright 2020 Google LLC.
# SPDX-License-Identifier: Apache-2.0

# %%
# The pip installation will install all necessary prerequisite packages for use of the core LIT package.
# !pip install lit-nlp
# Out:
# Requirement already satisfied: lit-nlp in /usr/local/lib/python3.11/dist-packages (1.3.1)
# Requirement already satisfied: absl-py>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.4.0)
# Requirement already satisfied: annoy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.17.3)
# Requirement already satisfied: attrs>=22.1.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (25.3.0)
# Requirement already satisfied: etils>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.5.0->lit-nlp) (1.12.2)
# Requirement already satisfied: filelock>=3.12.3 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (3.18.0)
# Requirement already satisfied: google-cloud-translate>=3.11.1 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (3.20.2)
# Requirement already satisfied: ipython>=7.34.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (7.34.0)
# Requirement already satisfied: Levenshtein>=0.21.1 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (0.27.1)
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (3.10.0)
# Requirement already satisfied: ml-collections>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.1.0)
# Collecting numpy<2.0.0,>=1.24.1 (from lit-nlp)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from pandas[output-formatting]>=2.0.3->lit-nlp) (2.2.2)
# Requirement already satisfied: Pillow>=10.0.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (11.2.1)
# Requirement already satisfied: portpicker>=1.5.2 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.5.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (2.32.3)
# Requirement already satisfied: rouge-score>=0.1.2 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (0.1.2)
# Requirement already satisfied: sacrebleu>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (2.5.1)
# Requirement already satisfied: saliency>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (0.2.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.6.1)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.15.3)
# Requirement already satisfied: shap<0.46.0,>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (0.45.1)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (1.17.0)
# Requirement already satisfied: termcolor>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (3.1.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (4.67.1)
# Requirement already satisfied: werkzeug>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from lit-nlp) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.5.0->lit-nlp) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.5.0->lit-nlp) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.5.0->lit-nlp) (4.13.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.5.0->lit-nlp) (3.21.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate>=3.11.1->lit-nlp) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-translate>=3.11.1->lit-nlp) (2.38.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from google-cloud-translate>=3.11.1->lit-nlp) (2.4.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-translate>=3.11.1->lit-nlp) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-translate>=3.11.1->lit-nlp) (5.29.4)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-translate>=3.11.1->lit-nlp) (0.14.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.34.0->lit-nlp) (4.9.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from Levenshtein>=0.21.1->lit-nlp) (3.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->lit-nlp) (2.9.0.post0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from ml-collections>=0.1.1->lit-nlp) (6.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.3->pandas[output-formatting]>=2.0.3->lit-nlp) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.3->pandas[output-formatting]>=2.0.3->lit-nlp) (2025.2)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from pandas[output-formatting]>=2.0.3->lit-nlp) (3.1.6)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from pandas[output-formatting]>=2.0.3->lit-nlp) (0.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from portpicker>=1.5.2->lit-nlp) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->lit-nlp) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->lit-nlp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->lit-nlp) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->lit-nlp) (2025.4.26)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.1.2->lit-nlp) (3.9.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=2.3.1->lit-nlp) (3.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=2.3.1->lit-nlp) (2024.11.6)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=2.3.1->lit-nlp) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=2.3.1->lit-nlp) (5.4.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from saliency>=0.1.3->lit-nlp) (0.25.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->lit-nlp) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->lit-nlp) (3.6.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap<0.46.0,>=0.42.0->lit-nlp) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from shap<0.46.0,>=0.42.0->lit-nlp) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap<0.46.0,>=0.42.0->lit-nlp) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=2.2.3->lit-nlp) (3.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate>=3.11.1->lit-nlp) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate>=3.11.1->lit-nlp) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate>=3.11.1->lit-nlp) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate>=3.11.1->lit-nlp) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate>=3.11.1->lit-nlp) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate>=3.11.1->lit-nlp) (4.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.34.0->lit-nlp) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.34.0->lit-nlp) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.34.0->lit-nlp) (0.2.13)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score>=0.1.2->lit-nlp) (8.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->shap<0.46.0,>=0.42.0->lit-nlp) (0.43.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->saliency>=0.1.3->lit-nlp) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->saliency>=0.1.3->lit-nlp) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->saliency>=0.1.3->lit-nlp) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->saliency>=0.1.3->lit-nlp) (0.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate>=3.11.1->lit-nlp) (0.6.1)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# !pip install "numpy>=2.0.0,<3.0.0"
# Out:
# Collecting numpy<3.0.0,>=2.0.0
#   Using cached numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lit-nlp 1.3.1 requires numpy<2.0.0,>=1.24.1, but you have numpy 2.2.5 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.5 which is incompatible.
# Successfully installed numpy-2.2.5

# %%
from lit_nlp import notebook
from lit_nlp.examples.glue import data
from lit_nlp.examples.glue import models

# Hide INFO and lower logs. Comment this out for debugging.
from absl import logging
logging.set_verbosity(logging.WARNING)

# %%
# Fetch the trained model weights
# !wget https://storage.googleapis.com/what-if-tool-resources/lit-models/sst2_tiny.tar.gz
# !tar -xvf sst2_tiny.tar.gz
# Out:
# --2025-05-16 03:16:49--  https://storage.googleapis.com/what-if-tool-resources/lit-models/sst2_tiny.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.23.207, 74.125.203.207, 74.125.204.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.23.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16362834 (16M) [application/octet-stream]
# Saving to: ‘sst2_tiny.tar.gz’
#
# sst2_tiny.tar.gz    100%[===================>]  15.60M  11.4MB/s    in 1.4s
#
# 2025-05-16 03:16:51 (11.4 MB/s) - ‘sst2_tiny.tar.gz’ saved [16362834/16362834]
#
# ./
# ./tokenizer_config.json
# ./tf_model.h5
# ./config.json
# ./train.history.json
# ./vocab.txt
# ./special_tokens_map.json

# %%
# Create the LIT widget with the model and dataset to analyze.
datasets = {'sst_dev': data.SST2Data('validation')}
models = {'sst_tiny': models.SST2Model('./')}

widget = notebook.LitWidget(models, datasets, port=8890)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/glue/sst2/2.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/glue/sst2/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/glue/sst2/incomplete.7XWRP0_2.0.0/glue-train.tfrecord*...:   0%|          …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/glue/sst2/incomplete.7XWRP0_2.0.0/glue-validation.tfrecord*...:   0%|     …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/glue/sst2/incomplete.7XWRP0_2.0.0/glue-test.tfrecord*...:   0%|          |…
# Dataset glue downloaded and prepared to /root/tensorflow_datasets/glue/sst2/2.0.0. Subsequent calls will reuse this data.
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at ./.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.
# WARNING:absl:Unable to infer init spec for dataset 'NoneDataset'. Unable to infer a type for parameter 'models' of '__init__'. Please add a type hint or default value, or implement a Spec literal.

# %%
# Render the widget
widget.render(height=1000)

# %% [markdown]
# If you've found interesting examples using the LIT UI, you can access these in Python using `widget.ui_state`:

# %%
widget.ui_state.primary  # the main selected datapoint
# Out:
# {'data': mappingproxy({'sentence': "audrey tatou has a knack for picking roles that magnify her outrageous charm , and in this literate french comedy , she 's as morning-glory exuberant as she was in amélie . ",
#                'label': '1',
#                '_id': '0c9ab2ff23795343031a64add431a718',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  'id': '0c9ab2ff23795343031a64add431a718',
#  'meta': {'added': None, 'parentId': None, 'source': None}}

# %%
widget.ui_state.selection  # the full selected set, if you have multiple points selected
# Out:
# [{'data': mappingproxy({'sentence': "it 's a charming and often affecting journey . ",
#                 'label': '1',
#                 '_id': '827559828a1681ba9d0d1ec718025cd2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '827559828a1681ba9d0d1ec718025cd2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'unflinchingly bleak and desperate ',
#                 'label': '0',
#                 '_id': '98d0ff1acb1b1736e8c79fd30ab8a58e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '98d0ff1acb1b1736e8c79fd30ab8a58e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'allows us to hope that nolan is poised to embark a major career as a commercial yet inventive filmmaker . ',
#                 'label': '1',
#                 '_id': '4f0e2708c7467f14fd7cd703a267cf1d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '4f0e2708c7467f14fd7cd703a267cf1d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales . ",
#                 'label': '1',
#                 '_id': 'eb90c48a2ebc4bf66e14382739e4d647',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'eb90c48a2ebc4bf66e14382739e4d647',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's slow -- very , very slow . ",
#                 'label': '0',
#                 '_id': 'fcedbabb26d0f144c01847689ff52730',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'fcedbabb26d0f144c01847689ff52730',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women . ',
#                 'label': '1',
#                 '_id': '5cbca5c6b6a27e2678aebda1e7eb1b70',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '5cbca5c6b6a27e2678aebda1e7eb1b70',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a sometimes tedious film . ',
#                 'label': '0',
#                 '_id': '32ec21d0940f29109e2e72ce9b6aac94',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '32ec21d0940f29109e2e72ce9b6aac94',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "or doing last year 's taxes with your ex-wife . ",
#                 'label': '0',
#                 '_id': 'a1a90b1d767a59f016bb4cbc7af2b145',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a1a90b1d767a59f016bb4cbc7af2b145',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance . ",
#                 'label': '1',
#                 '_id': 'df3932f52e6925981111126675d88c53',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'df3932f52e6925981111126675d88c53',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey . ",
#                 'label': '0',
#                 '_id': 'cb31a4f739fe4d8581cb12678a406fd9',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'cb31a4f739fe4d8581cb12678a406fd9',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the mesmerizing performances of the leads keep the film grounded and keep the audience riveted . ',
#                 'label': '1',
#                 '_id': 'd60a0d8e03cd70bdf3951572c9a0c68e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'd60a0d8e03cd70bdf3951572c9a0c68e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'it takes a strange kind of laziness to waste the talents of robert forster , anne meara , eugene levy , and reginald veljohnson all in the same movie . ',
#                 'label': '0',
#                 '_id': 'deda1e93d7eb865a6e1b1581e03a862e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'deda1e93d7eb865a6e1b1581e03a862e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': '... the film suffers from a lack of humor ( something needed to balance out the violence ) ... ',
#                 'label': '0',
#                 '_id': '89c7f194b5b929389aa019ee83f72d7d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '89c7f194b5b929389aa019ee83f72d7d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "we root for ( clara and paul ) , even like them , though perhaps it 's an emotion closer to pity . ",
#                 'label': '1',
#                 '_id': '8cb29256dac22dfaf9e6dad18a2f5b5c',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8cb29256dac22dfaf9e6dad18a2f5b5c',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "even horror fans will most likely not find what they 're seeking with trouble every day ; the movie lacks both thrills and humor . ",
#                 'label': '0',
#                 '_id': '03ff3abab73b4aeb5e34c328b20f38f8',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '03ff3abab73b4aeb5e34c328b20f38f8',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a gorgeous , high-spirited musical from india that exquisitely blends music , dance , song , and high drama . ',
#                 'label': '1',
#                 '_id': '26461ed148d353b5534091a19b5713f2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '26461ed148d353b5534091a19b5713f2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the emotions are raw and will strike a nerve with anyone who 's ever had family trauma . ",
#                 'label': '1',
#                 '_id': 'a550ca2540bc1e5b3c492d57887d8f70',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a550ca2540bc1e5b3c492d57887d8f70',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "audrey tatou has a knack for picking roles that magnify her outrageous charm , and in this literate french comedy , she 's as morning-glory exuberant as she was in amélie . ",
#                 'label': '1',
#                 '_id': '0c9ab2ff23795343031a64add431a718',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '0c9ab2ff23795343031a64add431a718',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': '... the movie is just a plain old monster . ',
#                 'label': '0',
#                 '_id': 'a2af809a01c4553c65d744e3892a817b',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a2af809a01c4553c65d744e3892a817b',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'in its best moments , resembles a bad high school production of grease , without benefit of song . ',
#                 'label': '0',
#                 '_id': 'e82bf14b98b3d0bd2aaf18a190ee30a5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e82bf14b98b3d0bd2aaf18a190ee30a5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'pumpkin takes an admirable look at the hypocrisy of political correctness , but it does so with such an uneven tone that you never know when humor ends and tragedy begins . ',
#                 'label': '0',
#                 '_id': 'c85832a1f9c2f59c5e9bb30918a79ba4',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'c85832a1f9c2f59c5e9bb30918a79ba4',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the iditarod lasts for days - this just felt like it did . ',
#                 'label': '0',
#                 '_id': '8aab3b3ea1be2750be9877ec7abdee3d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8aab3b3ea1be2750be9877ec7abdee3d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'holden caulfield did it better . ',
#                 'label': '0',
#                 '_id': '989060302551988ea326627988f55aac',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '989060302551988ea326627988f55aac',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a delectable and intriguing thriller filled with surprises , read my lips is an original . ',
#                 'label': '1',
#                 '_id': '65137aedfa80bb12cb917065ac2b00ea',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '65137aedfa80bb12cb917065ac2b00ea',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'seldom has a movie so closely matched the spirit of a man and his work . ',
#                 'label': '1',
#                 '_id': '696d4c20b25878da0a5c634010c28ce7',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '696d4c20b25878da0a5c634010c28ce7',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "nicks , seemingly uncertain what 's going to make people laugh , runs the gamut from stale parody to raunchy sex gags to formula romantic comedy . ",
#                 'label': '0',
#                 '_id': 'f932d8f4f74d0eac42fd5f756a95d718',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'f932d8f4f74d0eac42fd5f756a95d718',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the action switches between past and present , but the material link is too tenuous to anchor the emotional connections that purport to span a 125-year divide . ',
#                 'label': '0',
#                 '_id': '4fdc038d7c3ef7042882c430bab7b9e4',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '4fdc038d7c3ef7042882c430bab7b9e4',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's an offbeat treat that pokes fun at the democratic exercise while also examining its significance for those who take part . ",
#                 'label': '1',
#                 '_id': '919207b281e85185ff7af20ac647de7d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '919207b281e85185ff7af20ac647de7d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's a cookie-cutter movie , a cut-and-paste job . ",
#                 'label': '0',
#                 '_id': '8334d35060719860583f9506c7e051b1',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8334d35060719860583f9506c7e051b1',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'i had to look away - this was god awful . ',
#                 'label': '0',
#                 '_id': '6f35b1168fcfa03a01c9d57d7f57bd34',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '6f35b1168fcfa03a01c9d57d7f57bd34',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "thanks to scott 's charismatic roger and eisenberg 's sweet nephew , roger dodger is one of the most compelling variations on in the company of men . ",
#                 'label': '1',
#                 '_id': 'a566c948f34a1e1882968ab52123cb34',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a566c948f34a1e1882968ab52123cb34',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "... designed to provide a mix of smiles and tears , `` crossroads '' instead provokes a handful of unintentional howlers and numerous yawns . ",
#                 'label': '0',
#                 '_id': 'ca6525d1402add6718696461471cb71b',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'ca6525d1402add6718696461471cb71b',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a gorgeous , witty , seductive movie . ',
#                 'label': '1',
#                 '_id': 'a27e43cbe7f2de4fff0e667ec90b8156',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a27e43cbe7f2de4fff0e667ec90b8156',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "if the movie succeeds in instilling a wary sense of ` there but for the grace of god , ' it is far too self-conscious to draw you deeply into its world . ",
#                 'label': '0',
#                 '_id': 'ebafbec03e7d2d802d2e1cf71940010f',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'ebafbec03e7d2d802d2e1cf71940010f',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it does n't believe in itself , it has no sense of humor ... it 's just plain bored . ",
#                 'label': '0',
#                 '_id': '583f8d44de8aade7ce431feda7b33a22',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '583f8d44de8aade7ce431feda7b33a22',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "a sequence of ridiculous shoot - 'em - up scenes . ",
#                 'label': '0',
#                 '_id': '62bb273cc8b0ab1b3e35ae4e249f8cb7',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '62bb273cc8b0ab1b3e35ae4e249f8cb7',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the weight of the piece , the unerring professionalism of the chilly production , and the fascination embedded in the lurid topic prove recommendation enough . ',
#                 'label': '1',
#                 '_id': '63f88f0f8a9fbba2f36ec04325a39729',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '63f88f0f8a9fbba2f36ec04325a39729',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "( w ) hile long on amiable monkeys and worthy environmentalism , jane goodall 's wild chimpanzees is short on the thrills the oversize medium demands . ",
#                 'label': '0',
#                 '_id': '0723593d026c90e653734621a75f780c',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '0723593d026c90e653734621a75f780c',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'as surreal as a dream and as detailed as a photograph , as visually dexterous as it is at times imaginatively overwhelming . ',
#                 'label': '1',
#                 '_id': '8bf6e73dd7cafae801c6178eceb41e88',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8bf6e73dd7cafae801c6178eceb41e88',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'escaping the studio , piccoli is warmly affecting and so is this adroitly minimalist movie . ',
#                 'label': '1',
#                 '_id': '583e9379267559ee39af74f00c249f80',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '583e9379267559ee39af74f00c249f80',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "there 's ... tremendous energy from the cast , a sense of playfulness and excitement that seems appropriate . ",
#                 'label': '1',
#                 '_id': '774e9add9a298d087cb928f1072cc6b5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '774e9add9a298d087cb928f1072cc6b5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'this illuminating documentary transcends our preconceived vision of the holy land and its inhabitants , revealing the human complexities beneath . ',
#                 'label': '1',
#                 '_id': 'bce979d843cfd6bc3109ad87f8507fbf',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'bce979d843cfd6bc3109ad87f8507fbf',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the subtle strength of `` elling '' is that it never loses touch with the reality of the grim situation . ",
#                 'label': '1',
#                 '_id': 'a1bc96dca7fea69cd77eac9942f74202',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a1bc96dca7fea69cd77eac9942f74202',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'holm ... embodies the character with an effortlessly regal charisma . ',
#                 'label': '1',
#                 '_id': 'ae65ff5cb49035483e6a96cee43d86da',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'ae65ff5cb49035483e6a96cee43d86da',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the title not only describes its main characters , but the lazy people behind the camera as well . ',
#                 'label': '0',
#                 '_id': '81e0351260b6daab12ff2314061cbeb8',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '81e0351260b6daab12ff2314061cbeb8',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'it offers little beyond the momentary joys of pretty and weightless intellectual entertainment . ',
#                 'label': '0',
#                 '_id': 'dee9b4bf02ca4fa849b0b2c2fd557765',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'dee9b4bf02ca4fa849b0b2c2fd557765',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a synthesis of cliches and absurdities that seems positively decadent in its cinematic flash and emptiness . ',
#                 'label': '0',
#                 '_id': '1c4db1f89a3b584ae533cfa317d0479d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '1c4db1f89a3b584ae533cfa317d0479d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a subtle and well-crafted ( for the most part ) chiller . ',
#                 'label': '1',
#                 '_id': 'a26fb6e14c1b73b5d43f47afda4fd9f6',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a26fb6e14c1b73b5d43f47afda4fd9f6',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'has a lot of the virtues of eastwood at his best . ',
#                 'label': '1',
#                 '_id': 'bfb0a24a987da30550b1d48424070a0e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'bfb0a24a987da30550b1d48424070a0e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's hampered by a lifetime-channel kind of plot and a lead actress who is out of her depth . ",
#                 'label': '0',
#                 '_id': '832a53d178a67e537d6e551fb0c00018',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '832a53d178a67e537d6e551fb0c00018',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'it feels like an after-school special gussied up with some fancy special effects , and watching its rote plot points connect is about as exciting as gazing at an egg timer for 93 minutes . ',
#                 'label': '0',
#                 '_id': 'eefd97dd68869571c7472d6af94580cb',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'eefd97dd68869571c7472d6af94580cb',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "for the most part , director anne-sophie birot 's first feature is a sensitive , extraordinarily well-acted drama . ",
#                 'label': '1',
#                 '_id': '7bda7c5756e7043ef00ea25b0a0b2cc7',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '7bda7c5756e7043ef00ea25b0a0b2cc7',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'mr. tsai is a very original artist in his medium , and what time is it there ? ',
#                 'label': '1',
#                 '_id': '769dcb06500c978240549103fd7ef55e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '769dcb06500c978240549103fd7ef55e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'sade is an engaging look at the controversial eponymous and fiercely atheistic hero . ',
#                 'label': '1',
#                 '_id': '2c0c84a1ddd61f93e8fe92a9c8ae8d60',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '2c0c84a1ddd61f93e8fe92a9c8ae8d60',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'so devoid of any kind of intelligible story that it makes films like xxx and collateral damage seem like thoughtful treatises ',
#                 'label': '0',
#                 '_id': 'fc5d89eff8d4716e70da03b0bea049ff',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'fc5d89eff8d4716e70da03b0bea049ff',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a tender , heartfelt family drama . ',
#                 'label': '1',
#                 '_id': '37db2a297793059967134799629dbbab',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '37db2a297793059967134799629dbbab',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': '... a hollow joke told by a cinematic gymnast having too much fun embellishing the misanthropic tale to actually engage it . ',
#                 'label': '0',
#                 '_id': '070d812381d16ed96fd2a312b6fa25f5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '070d812381d16ed96fd2a312b6fa25f5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the cold turkey would 've been a far better title . ",
#                 'label': '0',
#                 '_id': '4d4501cc39f823eb926c5da1c35a8bd7',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '4d4501cc39f823eb926c5da1c35a8bd7',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'manages to be both repulsively sadistic and mundane . ',
#                 'label': '0',
#                 '_id': '6239bb3f161b0ff801f0cbce652aa6b0',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '6239bb3f161b0ff801f0cbce652aa6b0',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's just disappointingly superficial -- a movie that has all the elements necessary to be a fascinating , involving character study , but never does more than scratch the surface . ",
#                 'label': '0',
#                 '_id': '0fe0b8bd49fec5f46a2535988b0e4515',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '0fe0b8bd49fec5f46a2535988b0e4515',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "this is a story of two misfits who do n't stand a chance alone , but together they are magnificent . ",
#                 'label': '1',
#                 '_id': '31db54ba03c12aa2861b743bb5b66281',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '31db54ba03c12aa2861b743bb5b66281',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'schaeffer has to find some hook on which to hang his persistently useless movies , and it might as well be the resuscitation of the middle-aged character . ',
#                 'label': '0',
#                 '_id': '7a9637637502b2642d8e624c50af8bd1',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '7a9637637502b2642d8e624c50af8bd1',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the primitive force of this film seems to bubble up from the vast collective memory of the combatants . ',
#                 'label': '1',
#                 '_id': '414cda3b044d0a1931acc5b9098728d4',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '414cda3b044d0a1931acc5b9098728d4',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'on this tricky topic , tadpole is very much a step in the right direction , with its blend of frankness , civility and compassion . ',
#                 'label': '1',
#                 '_id': 'e09ddaacddb1038230935c423302d3b2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e09ddaacddb1038230935c423302d3b2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the script kicks in , and mr. hartley 's distended pace and foot-dragging rhythms follow . ",
#                 'label': '0',
#                 '_id': '0d0788579d57448ebf2cb7deff3b6f85',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '0d0788579d57448ebf2cb7deff3b6f85',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "you wonder why enough was n't just a music video rather than a full-length movie . ",
#                 'label': '0',
#                 '_id': 'c412a1c48d0b34410082badeea688170',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'c412a1c48d0b34410082badeea688170',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "if you 're hard up for raunchy college humor , this is your ticket right here . ",
#                 'label': '1',
#                 '_id': 'e1e5a538f6e848849a3627a42802c476',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e1e5a538f6e848849a3627a42802c476',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a fast , funny , highly enjoyable movie . ',
#                 'label': '1',
#                 '_id': '8a0ef9204dcc919cb4e01f151f85c993',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8a0ef9204dcc919cb4e01f151f85c993',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'good old-fashioned slash-and-hack is back ! ',
#                 'label': '1',
#                 '_id': 'e569cc5df1f0e6d513bdf5f51c5cc3f5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e569cc5df1f0e6d513bdf5f51c5cc3f5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'this one is definitely one to skip , even for horror movie fanatics . ',
#                 'label': '0',
#                 '_id': '667dbfdb8dd6f899a465bd5697a2c5e0',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '667dbfdb8dd6f899a465bd5697a2c5e0',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'for all its impressive craftsmanship , and despite an overbearing series of third-act crescendos , lily chou-chou never really builds up a head of emotional steam . ',
#                 'label': '0',
#                 '_id': '864064d96d8848c02e8db2beee41a2f2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '864064d96d8848c02e8db2beee41a2f2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'exquisitely nuanced in mood tics and dialogue , this chamber drama is superbly acted by the deeply appealing veteran bouquet and the chilling but quite human berling . ',
#                 'label': '1',
#                 '_id': '3e36ce0466bc86fb0c8ff414e6268353',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '3e36ce0466bc86fb0c8ff414e6268353',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'uses high comedy to evoke surprising poignance . ',
#                 'label': '1',
#                 '_id': '84dcba4a072f056ce3c42a6c9a0a5952',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '84dcba4a072f056ce3c42a6c9a0a5952',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'one of creepiest , scariest movies to come along in a long , long time , easily rivaling blair witch or the others . ',
#                 'label': '1',
#                 '_id': '148b38f60c49d8918d47e15b6ddc0aa5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '148b38f60c49d8918d47e15b6ddc0aa5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a string of rehashed sight gags based in insipid vulgarity . ',
#                 'label': '0',
#                 '_id': '1958dfc45aa44de7e2e7d30be087e51b',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '1958dfc45aa44de7e2e7d30be087e51b',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "among the year 's most intriguing explorations of alientation . ",
#                 'label': '1',
#                 '_id': '06038fe0bd54559e51694ece3cbd5fd2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '06038fe0bd54559e51694ece3cbd5fd2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the movie fails to live up to the sum of its parts . ',
#                 'label': '0',
#                 '_id': 'b9a3c05e7aa75131c70f90803276f523',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'b9a3c05e7aa75131c70f90803276f523',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the son 's room is a triumph of gentility that earns its moments of pathos . ",
#                 'label': '1',
#                 '_id': '3846902d2abbeed83cfce47d99f52892',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '3846902d2abbeed83cfce47d99f52892',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'there is nothing outstanding about this film , but it is good enough and will likely be appreciated most by sailors and folks who know their way around a submarine . ',
#                 'label': '1',
#                 '_id': 'f0c80052d95df962116bca4960f2af57',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'f0c80052d95df962116bca4960f2af57',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'this is a train wreck of an action film -- a stupefying attempt by the filmmakers to force-feed james bond into the mindless xxx mold and throw 40 years of cinematic history down the toilet in favor of bright flashes and loud bangs . ',
#                 'label': '0',
#                 '_id': 'd48b5f98d0438aa546633dd03effb951',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'd48b5f98d0438aa546633dd03effb951',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the draw ( for `` big bad love '' ) is a solid performance by arliss howard . ",
#                 'label': '1',
#                 '_id': '55e07592e90e5101ce8050fe8695a2a0',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '55e07592e90e5101ce8050fe8695a2a0',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'green might want to hang onto that ski mask , as robbery may be the only way to pay for his next project . ',
#                 'label': '0',
#                 '_id': '71ea6fee593695e2e79aeb949892473d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '71ea6fee593695e2e79aeb949892473d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's one pussy-ass world when even killer-thrillers revolve around group therapy sessions . ",
#                 'label': '0',
#                 '_id': '1370b4cb2d09e46dc32c99b2ed4c4aa5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '1370b4cb2d09e46dc32c99b2ed4c4aa5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "though it 's become almost redundant to say so , major kudos go to leigh for actually casting people who look working-class . ",
#                 'label': '1',
#                 '_id': '963d64e2426dfa78ea1b8251f50ed243',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '963d64e2426dfa78ea1b8251f50ed243',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the band 's courage in the face of official repression is inspiring , especially for aging hippies ( this one included ) . ",
#                 'label': '1',
#                 '_id': 'a71b11500b53071f75b11ebbe4c1feea',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'a71b11500b53071f75b11ebbe4c1feea',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the movie achieves as great an impact by keeping these thoughts hidden as ... ( quills ) did by showing them . ',
#                 'label': '1',
#                 '_id': '32303ceaf2f48f3cfd384ac28b2fe92a',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '32303ceaf2f48f3cfd384ac28b2fe92a',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the film flat lines when it should peak and is more missed opportunity and trifle than dark , decadent truffle . ',
#                 'label': '0',
#                 '_id': 'e6badcc64558af908b9c69f304590ffe',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e6badcc64558af908b9c69f304590ffe',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'jaglom ... put ( s ) the audience in the privileged position of eavesdropping on his characters ',
#                 'label': '1',
#                 '_id': '29a6e16efe1367629a9d2a52e41a35b1',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '29a6e16efe1367629a9d2a52e41a35b1',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "fresnadillo 's dark and jolting images have a way of plying into your subconscious like the nightmare you had a week ago that wo n't go away . ",
#                 'label': '1',
#                 '_id': '9e79eeb457403d8878cb74b1009ffe63',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '9e79eeb457403d8878cb74b1009ffe63',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "we know the plot 's a little crazy , but it held my interest from start to finish . ",
#                 'label': '1',
#                 '_id': 'fb8c07949a05dc46e98e0e2b1646d94f',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'fb8c07949a05dc46e98e0e2b1646d94f',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's a scattershot affair , but when it hits its mark it 's brilliant . ",
#                 'label': '1',
#                 '_id': 'f8ad8b762f425e330cdffe99f236032f',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'f8ad8b762f425e330cdffe99f236032f',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'hardly a masterpiece , but it introduces viewers to a good charitable enterprise and some interesting real people . ',
#                 'label': '1',
#                 '_id': '78d96c5a50e03c3a09992a279c81a624',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '78d96c5a50e03c3a09992a279c81a624',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "you wo n't like roger , but you will quickly recognize him . ",
#                 'label': '0',
#                 '_id': '21447e18cfdac8ecd452b7687904999e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '21447e18cfdac8ecd452b7687904999e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "if steven soderbergh 's ` solaris ' is a failure it is a glorious failure . ",
#                 'label': '1',
#                 '_id': 'd15b7dcab382dbe199d9c2214d72ba03',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'd15b7dcab382dbe199d9c2214d72ba03',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'byler reveals his characters in a way that intrigues and even fascinates us , and he never reduces the situation to simple melodrama . ',
#                 'label': '1',
#                 '_id': '1019aa6ad8d7a815a200bdd72a2de136',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '1019aa6ad8d7a815a200bdd72a2de136',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'this riveting world war ii moral suspense story deals with the shadow side of american culture : racial prejudice in its ugly and diverse forms . ',
#                 'label': '0',
#                 '_id': '1b626b1e2ace23403888ef20ed84d056',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '1b626b1e2ace23403888ef20ed84d056',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's difficult to imagine the process that produced such a script , but here 's guessing that spray cheese and underarm noises played a crucial role . ",
#                 'label': '0',
#                 '_id': '96426a12052b9fa376684a6e96bea904',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '96426a12052b9fa376684a6e96bea904',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'no sophomore slump for director sam mendes , who segues from oscar winner to oscar-winning potential with a smooth sleight of hand . ',
#                 'label': '1',
#                 '_id': 'ecc26709e5edd4c62d35adce7d60cafa',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'ecc26709e5edd4c62d35adce7d60cafa',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'on the whole , the movie lacks wit , feeling and believability to compensate for its incessant coarseness and banality . ',
#                 'label': '0',
#                 '_id': 'e41e4e3989c65dde6b853f3f10d9e117',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e41e4e3989c65dde6b853f3f10d9e117',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'why make a documentary about these marginal historical figures ? ',
#                 'label': '0',
#                 '_id': '7a120bf46d75385b0a6c57742b124393',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '7a120bf46d75385b0a6c57742b124393',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'neither parker nor donovan is a typical romantic lead , but they bring a fresh , quirky charm to the formula . ',
#                 'label': '1',
#                 '_id': '40aba998232b4991a78786e8b2b0dae5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '40aba998232b4991a78786e8b2b0dae5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'his last movie was poetically romantic and full of indelible images , but his latest has nothing going for it . ',
#                 'label': '0',
#                 '_id': '3a4921f99effdb518cf156b8055a4aad',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '3a4921f99effdb518cf156b8055a4aad',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'does paint some memorable images ... , but makhmalbaf keeps her distance from the characters ',
#                 'label': '1',
#                 '_id': 'f1e8d7d0e4c0d287748df327afbdd436',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'f1e8d7d0e4c0d287748df327afbdd436',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a gripping movie , played with performances that are all understated and touching . ',
#                 'label': '1',
#                 '_id': 'b7b1bf8c446c5fa0b1d7fc3375621842',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'b7b1bf8c446c5fa0b1d7fc3375621842',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's one of those baseball pictures where the hero is stoic , the wife is patient , the kids are as cute as all get-out and the odds against success are long enough to intimidate , but short enough to make a dream seem possible . ",
#                 'label': '1',
#                 '_id': '378469fd00ca69c0741fb867f4a58a6a',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '378469fd00ca69c0741fb867f4a58a6a',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "combining quick-cut editing and a blaring heavy metal much of the time , beck seems to be under the illusion that he 's shooting the latest system of a down video . ",
#                 'label': '0',
#                 '_id': 'd34bba9332b5dabb54c8cf4b887bb20d',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'd34bba9332b5dabb54c8cf4b887bb20d',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the movie 's relatively simple plot and uncomplicated morality play well with the affable cast . ",
#                 'label': '1',
#                 '_id': '14d7b0d78c1c378c5419d4853b85d3aa',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '14d7b0d78c1c378c5419d4853b85d3aa',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "what the director ca n't do is make either of val kilmer 's two personas interesting or worth caring about . ",
#                 'label': '0',
#                 '_id': '12c4b8cfc761088a7eae2b56928991f2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '12c4b8cfc761088a7eae2b56928991f2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "too often , the viewer is n't reacting to humor so much as they are wincing back in repugnance . ",
#                 'label': '0',
#                 '_id': '5c244d9cd999191aa0fd52075f288854',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '5c244d9cd999191aa0fd52075f288854',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's great escapist fun that recreates a place and time that will never happen again . ",
#                 'label': '1',
#                 '_id': '706112b3f09654ec7b3ac35c39586ada',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '706112b3f09654ec7b3ac35c39586ada',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'scores no points for originality , wit , or intelligence . ',
#                 'label': '0',
#                 '_id': '73a74799c4184a7e08f7aa5c8f8fd032',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '73a74799c4184a7e08f7aa5c8f8fd032',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "there is n't nearly enough fun here , despite the presence of some appealing ingredients . ",
#                 'label': '0',
#                 '_id': 'd0e13898cbe3c0ccbf144da90c2916ff',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'd0e13898cbe3c0ccbf144da90c2916ff',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'hilariously inept and ridiculous . ',
#                 'label': '1',
#                 '_id': '8ba65c9e77fa882aba5a4598650e3d6f',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8ba65c9e77fa882aba5a4598650e3d6f',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'this movie is maddening . ',
#                 'label': '0',
#                 '_id': '96ad46c7922fad83a28a5c818620a3fd',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '96ad46c7922fad83a28a5c818620a3fd',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it haunts you , you ca n't forget it , you admire its conception and are able to resolve some of the confusions you had while watching it . ",
#                 'label': '1',
#                 '_id': '8268f2d6eeefbc76a95e1a5ee4ead443',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '8268f2d6eeefbc76a95e1a5ee4ead443',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'sam mendes has become valedictorian at the school for soft landings and easy ways out . ',
#                 'label': '0',
#                 '_id': 'dbf2121bb054d63812619b4685eae892',
# ...
#                 'label': '1',
#                 '_id': '4d85b41fe192746a4d1affc3ea01b5ca',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '4d85b41fe192746a4d1affc3ea01b5ca',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a giggle-inducing comedy with snappy dialogue and winning performances by an unlikely team of oscar-winners : susan sarandon and goldie hawn . ',
#                 'label': '1',
#                 '_id': '3ff547509d47b30fcc9b3af597f0f142',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '3ff547509d47b30fcc9b3af597f0f142',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's too self-important and plodding to be funny , and too clipped and abbreviated to be an epic . ",
#                 'label': '0',
#                 '_id': '6d9bca654e67c55eb4d14bc2e6c58a2e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '6d9bca654e67c55eb4d14bc2e6c58a2e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'will amuse and provoke adventurous adults in specialty venues . ',
#                 'label': '1',
#                 '_id': '71c4d5af5a2f9b308547bedd7c1a4b35',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '71c4d5af5a2f9b308547bedd7c1a4b35',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'sometimes seems less like storytelling than something the otherwise compelling director needed to get off his chest . ',
#                 'label': '0',
#                 '_id': 'da1afa0edf904467ea034e878be007ab',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'da1afa0edf904467ea034e878be007ab',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'but this films lacks the passion required to sell the material . ',
#                 'label': '0',
#                 '_id': 'ed2ab96bbe51d53364a6d63bf5f7fe84',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'ed2ab96bbe51d53364a6d63bf5f7fe84',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'what is 100 % missing here is a script of even the most elemental literacy , an inkling of genuine wit , and anything resembling acting . ',
#                 'label': '0',
#                 '_id': '297df04e1d124c836c4fc01adde08502',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '297df04e1d124c836c4fc01adde08502',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "there 's a wickedly subversive bent to the best parts of birthday girl . ",
#                 'label': '1',
#                 '_id': '69342bd7e3b29bfc2e4668476c9bddbc',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '69342bd7e3b29bfc2e4668476c9bddbc',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a better title , for all concerned , might be swept under the rug . ',
#                 'label': '0',
#                 '_id': 'e04a6bf2305157236d4c86b3ef9f9f68',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e04a6bf2305157236d4c86b3ef9f9f68',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a wildly inconsistent emotional experience . ',
#                 'label': '0',
#                 '_id': '236510ab246b58b6b74cc443a9a3d67e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '236510ab246b58b6b74cc443a9a3d67e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'given how heavy-handed and portent-heavy it is , this could be the worst thing soderbergh has ever done . ',
#                 'label': '0',
#                 '_id': '47ee2e7f4101cceb8d6ca61c368cb3d3',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '47ee2e7f4101cceb8d6ca61c368cb3d3',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'despite the evocative aesthetics evincing the hollow state of modern love life , the film never percolates beyond a monotonous whine . ',
#                 'label': '0',
#                 '_id': 'aad16a43a93d3d70a0a85c4ee9ef7556',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'aad16a43a93d3d70a0a85c4ee9ef7556',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'an absurdist comedy about alienation , separation and loss . ',
#                 'label': '0',
#                 '_id': 'f427bd13ee398c9a374f6a9c962ff3ab',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'f427bd13ee398c9a374f6a9c962ff3ab',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "... mafia , rap stars and hood rats butt their ugly heads in a regurgitation of cinematic violence that gives brutal birth to an unlikely , but likable , hero . ' ",
#                 'label': '1',
#                 '_id': 'faaa731a36cf7ba899ba8033a0bb0432',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'faaa731a36cf7ba899ba8033a0bb0432',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'his healthy sense of satire is light and fun ... ',
#                 'label': '1',
#                 '_id': 'edcbbe536564abb6a10200f7e787bd4f',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'edcbbe536564abb6a10200f7e787bd4f',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'trademark american triteness and simplicity are tossed out the window with the intelligent french drama that deftly explores the difficult relationship between a father and son . ',
#                 'label': '1',
#                 '_id': 'eeddbe5afd623d0d79e6ac5fdfafffc2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'eeddbe5afd623d0d79e6ac5fdfafffc2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'miller is playing so free with emotions , and the fact that children are hostages to fortune , that he makes the audience hostage to his swaggering affectation of seriousness . ',
#                 'label': '1',
#                 '_id': '6f0d35a468a19fbda67ac0a3cf8ee700',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '6f0d35a468a19fbda67ac0a3cf8ee700',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "impostor has a handful of thrilling moments and a couple of good performances , but the movie does n't quite fly . ",
#                 'label': '0',
#                 '_id': 'fc5e8c3e7bbf894d966a4f11ad40b2d1',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'fc5e8c3e7bbf894d966a4f11ad40b2d1',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'part low rent godfather . ',
#                 'label': '0',
#                 '_id': '171c93d8fd4be1288e9cce83ef2721e5',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '171c93d8fd4be1288e9cce83ef2721e5',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': '( serry ) wants to blend politics and drama , an admirable ambition . ',
#                 'label': '1',
#                 '_id': 'c34d4a62a5ac600140ced2d3235683c0',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'c34d4a62a5ac600140ced2d3235683c0',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "for all the writhing and wailing , tears , rage and opium overdoses , there 's no sense of actual passion being washed away in love 's dissolution . ",
#                 'label': '0',
#                 '_id': '3d6749f6879347267c35a2364efa3320',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '3d6749f6879347267c35a2364efa3320',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's fascinating to see how bettany and mcdowell play off each other . ",
#                 'label': '1',
#                 '_id': 'c29a820e53e33c3158144095d07e9dfe',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'c29a820e53e33c3158144095d07e9dfe',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'in a way , the film feels like a breath of fresh air , but only to those that allow it in . ',
#                 'label': '1',
#                 '_id': '99fdebf210f4e92eaede84963113c281',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '99fdebf210f4e92eaede84963113c281',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'visually imaginative , thematically instructive and thoroughly delightful , it takes us on a roller-coaster ride from innocence to experience without even a hint of that typical kiddie-flick sentimentality . ',
#                 'label': '1',
#                 '_id': '51b77498c573d9c02b2fd699d3f135af',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '51b77498c573d9c02b2fd699d3f135af',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "the film 's welcome breeziness and some unbelievably hilarious moments -- most portraying the idiocy of the film industry -- make it mostly worth the trip . ",
#                 'label': '1',
#                 '_id': '6bfd6ac7f5e37d2f6e35d9146612baf7',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '6bfd6ac7f5e37d2f6e35d9146612baf7',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "add yet another hat to a talented head , clooney 's a good director . ",
#                 'label': '1',
#                 '_id': '029a4ab954c138f225fc441d284d607e',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '029a4ab954c138f225fc441d284d607e',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "stephen rea , aidan quinn , and alan bates play desmond 's legal eagles , and when joined by brosnan , the sight of this grandiloquent quartet lolling in pretty irish settings is a pleasant enough thing , ` tis . ",
#                 'label': '1',
#                 '_id': '6b36688a593216ece4ef5f6d00f766e6',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '6b36688a593216ece4ef5f6d00f766e6',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "bennett 's naturalistic performance speaks volumes more truth than any ` reality ' show , and anybody contemplating their own drastic life changes should watch some body first . ",
#                 'label': '1',
#                 '_id': '68163ff87cfbccaf99a76439ae5bf0dd',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '68163ff87cfbccaf99a76439ae5bf0dd',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "it 's inoffensive , cheerful , built to inspire the young people , set to an unending soundtrack of beach party pop numbers and aside from its remarkable camerawork and awesome scenery , it 's about as exciting as a sunburn . ",
#                 'label': '0',
#                 '_id': '50387b9037c9681c8c81fb9f0ac02f9f',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '50387b9037c9681c8c81fb9f0ac02f9f',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "while it 's genuinely cool to hear characters talk about early rap records ( sugar hill gang , etc. ) , the constant referencing of hip-hop arcana can alienate even the savviest audiences . ",
#                 'label': '0',
#                 '_id': '147b2a558a7a6b2734833f4db56f14ff',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '147b2a558a7a6b2734833f4db56f14ff',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'dull , lifeless , and amateurishly assembled . ',
#                 'label': '0',
#                 '_id': 'bfcdd41df38c1ba01fcfc0cb2f883abe',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'bfcdd41df38c1ba01fcfc0cb2f883abe',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "mcconaughey 's fun to watch , the dragons are okay , not much fire in the script . ",
#                 'label': '1',
#                 '_id': 'be94c61e6d638a6cc68fa57a4ea3afe8',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'be94c61e6d638a6cc68fa57a4ea3afe8',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'the far future may be awesome to consider , but from period detail to matters of the heart , this film is most transporting when it stays put in the past . ',
#                 'label': '1',
#                 '_id': '186a86f56e6677cee80e88c89d1cae48',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '186a86f56e6677cee80e88c89d1cae48',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'has all the depth of a wading pool . ',
#                 'label': '0',
#                 '_id': 'abc041da5bae0513f503130e3282a216',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'abc041da5bae0513f503130e3282a216',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a movie with a real anarchic flair . ',
#                 'label': '1',
#                 '_id': 'e0cb3f3d1128ad034856dbf291ce8d02',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': 'e0cb3f3d1128ad034856dbf291ce8d02',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': 'a subject like this should inspire reaction in its audience ; the pianist does not . ',
#                 'label': '0',
#                 '_id': '4670ae724396b055f104454e59c6ada0',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '4670ae724396b055f104454e59c6ada0',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': '... is an arthritic attempt at directing by callie khouri . ',
#                 'label': '0',
#                 '_id': '7eb70385acd55b87322b8325c90723e2',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '7eb70385acd55b87322b8325c90723e2',
#   'meta': {'added': None, 'parentId': None, 'source': None}},
#  {'data': mappingproxy({'sentence': "looking aristocratic , luminous yet careworn in jane hamilton 's exemplary costumes , rampling gives a performance that could not be improved upon . ' ",
#                 'label': '1',
#                 '_id': '3e13ace95d5fe2de92f4b9683db14d36',
#                 '_meta': {'added': None, 'parentId': None, 'source': None}}),
#   'id': '3e13ace95d5fe2de92f4b9683db14d36',
#   'meta': {'added': None, 'parentId': None, 'source': None}}]

# %%
widget.ui_state.pinned  # the pinned datapoint, if you use the 📌 icon or comparison mode

# %% [markdown]
# Note that these include some metadata; the bare example is in the `['data']` field for each record:

# %%
widget.ui_state.primary['data']
# Out:
# mappingproxy({'sentence': 'in its best moments , resembles a bad high school production of grease , without benefit of song . ',
#               'label': '0',
#               '_id': 'e82bf14b98b3d0bd2aaf18a190ee30a5',
#               '_meta': {'added': None, 'parentId': None, 'source': None}})

# %%
[ex['data'] for ex in widget.ui_state.selection]
# Out:
# [mappingproxy({'sentence': "it 's a charming and often affecting journey . ",
#                'label': '1',
#                '_id': '827559828a1681ba9d0d1ec718025cd2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'unflinchingly bleak and desperate ',
#                'label': '0',
#                '_id': '98d0ff1acb1b1736e8c79fd30ab8a58e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'allows us to hope that nolan is poised to embark a major career as a commercial yet inventive filmmaker . ',
#                'label': '1',
#                '_id': '4f0e2708c7467f14fd7cd703a267cf1d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales . ",
#                'label': '1',
#                '_id': 'eb90c48a2ebc4bf66e14382739e4d647',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's slow -- very , very slow . ",
#                'label': '0',
#                '_id': 'fcedbabb26d0f144c01847689ff52730',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women . ',
#                'label': '1',
#                '_id': '5cbca5c6b6a27e2678aebda1e7eb1b70',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a sometimes tedious film . ',
#                'label': '0',
#                '_id': '32ec21d0940f29109e2e72ce9b6aac94',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "or doing last year 's taxes with your ex-wife . ",
#                'label': '0',
#                '_id': 'a1a90b1d767a59f016bb4cbc7af2b145',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance . ",
#                'label': '1',
#                '_id': 'df3932f52e6925981111126675d88c53',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey . ",
#                'label': '0',
#                '_id': 'cb31a4f739fe4d8581cb12678a406fd9',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the mesmerizing performances of the leads keep the film grounded and keep the audience riveted . ',
#                'label': '1',
#                '_id': 'd60a0d8e03cd70bdf3951572c9a0c68e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it takes a strange kind of laziness to waste the talents of robert forster , anne meara , eugene levy , and reginald veljohnson all in the same movie . ',
#                'label': '0',
#                '_id': 'deda1e93d7eb865a6e1b1581e03a862e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': '... the film suffers from a lack of humor ( something needed to balance out the violence ) ... ',
#                'label': '0',
#                '_id': '89c7f194b5b929389aa019ee83f72d7d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "we root for ( clara and paul ) , even like them , though perhaps it 's an emotion closer to pity . ",
#                'label': '1',
#                '_id': '8cb29256dac22dfaf9e6dad18a2f5b5c',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "even horror fans will most likely not find what they 're seeking with trouble every day ; the movie lacks both thrills and humor . ",
#                'label': '0',
#                '_id': '03ff3abab73b4aeb5e34c328b20f38f8',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a gorgeous , high-spirited musical from india that exquisitely blends music , dance , song , and high drama . ',
#                'label': '1',
#                '_id': '26461ed148d353b5534091a19b5713f2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the emotions are raw and will strike a nerve with anyone who 's ever had family trauma . ",
#                'label': '1',
#                '_id': 'a550ca2540bc1e5b3c492d57887d8f70',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "audrey tatou has a knack for picking roles that magnify her outrageous charm , and in this literate french comedy , she 's as morning-glory exuberant as she was in amélie . ",
#                'label': '1',
#                '_id': '0c9ab2ff23795343031a64add431a718',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': '... the movie is just a plain old monster . ',
#                'label': '0',
#                '_id': 'a2af809a01c4553c65d744e3892a817b',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'in its best moments , resembles a bad high school production of grease , without benefit of song . ',
#                'label': '0',
#                '_id': 'e82bf14b98b3d0bd2aaf18a190ee30a5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'pumpkin takes an admirable look at the hypocrisy of political correctness , but it does so with such an uneven tone that you never know when humor ends and tragedy begins . ',
#                'label': '0',
#                '_id': 'c85832a1f9c2f59c5e9bb30918a79ba4',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the iditarod lasts for days - this just felt like it did . ',
#                'label': '0',
#                '_id': '8aab3b3ea1be2750be9877ec7abdee3d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'holden caulfield did it better . ',
#                'label': '0',
#                '_id': '989060302551988ea326627988f55aac',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a delectable and intriguing thriller filled with surprises , read my lips is an original . ',
#                'label': '1',
#                '_id': '65137aedfa80bb12cb917065ac2b00ea',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'seldom has a movie so closely matched the spirit of a man and his work . ',
#                'label': '1',
#                '_id': '696d4c20b25878da0a5c634010c28ce7',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "nicks , seemingly uncertain what 's going to make people laugh , runs the gamut from stale parody to raunchy sex gags to formula romantic comedy . ",
#                'label': '0',
#                '_id': 'f932d8f4f74d0eac42fd5f756a95d718',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the action switches between past and present , but the material link is too tenuous to anchor the emotional connections that purport to span a 125-year divide . ',
#                'label': '0',
#                '_id': '4fdc038d7c3ef7042882c430bab7b9e4',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's an offbeat treat that pokes fun at the democratic exercise while also examining its significance for those who take part . ",
#                'label': '1',
#                '_id': '919207b281e85185ff7af20ac647de7d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's a cookie-cutter movie , a cut-and-paste job . ",
#                'label': '0',
#                '_id': '8334d35060719860583f9506c7e051b1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'i had to look away - this was god awful . ',
#                'label': '0',
#                '_id': '6f35b1168fcfa03a01c9d57d7f57bd34',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "thanks to scott 's charismatic roger and eisenberg 's sweet nephew , roger dodger is one of the most compelling variations on in the company of men . ",
#                'label': '1',
#                '_id': 'a566c948f34a1e1882968ab52123cb34',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "... designed to provide a mix of smiles and tears , `` crossroads '' instead provokes a handful of unintentional howlers and numerous yawns . ",
#                'label': '0',
#                '_id': 'ca6525d1402add6718696461471cb71b',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a gorgeous , witty , seductive movie . ',
#                'label': '1',
#                '_id': 'a27e43cbe7f2de4fff0e667ec90b8156',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "if the movie succeeds in instilling a wary sense of ` there but for the grace of god , ' it is far too self-conscious to draw you deeply into its world . ",
#                'label': '0',
#                '_id': 'ebafbec03e7d2d802d2e1cf71940010f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it does n't believe in itself , it has no sense of humor ... it 's just plain bored . ",
#                'label': '0',
#                '_id': '583f8d44de8aade7ce431feda7b33a22',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "a sequence of ridiculous shoot - 'em - up scenes . ",
#                'label': '0',
#                '_id': '62bb273cc8b0ab1b3e35ae4e249f8cb7',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the weight of the piece , the unerring professionalism of the chilly production , and the fascination embedded in the lurid topic prove recommendation enough . ',
#                'label': '1',
#                '_id': '63f88f0f8a9fbba2f36ec04325a39729',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "( w ) hile long on amiable monkeys and worthy environmentalism , jane goodall 's wild chimpanzees is short on the thrills the oversize medium demands . ",
#                'label': '0',
#                '_id': '0723593d026c90e653734621a75f780c',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'as surreal as a dream and as detailed as a photograph , as visually dexterous as it is at times imaginatively overwhelming . ',
#                'label': '1',
#                '_id': '8bf6e73dd7cafae801c6178eceb41e88',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'escaping the studio , piccoli is warmly affecting and so is this adroitly minimalist movie . ',
#                'label': '1',
#                '_id': '583e9379267559ee39af74f00c249f80',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "there 's ... tremendous energy from the cast , a sense of playfulness and excitement that seems appropriate . ",
#                'label': '1',
#                '_id': '774e9add9a298d087cb928f1072cc6b5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'this illuminating documentary transcends our preconceived vision of the holy land and its inhabitants , revealing the human complexities beneath . ',
#                'label': '1',
#                '_id': 'bce979d843cfd6bc3109ad87f8507fbf',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the subtle strength of `` elling '' is that it never loses touch with the reality of the grim situation . ",
#                'label': '1',
#                '_id': 'a1bc96dca7fea69cd77eac9942f74202',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'holm ... embodies the character with an effortlessly regal charisma . ',
#                'label': '1',
#                '_id': 'ae65ff5cb49035483e6a96cee43d86da',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the title not only describes its main characters , but the lazy people behind the camera as well . ',
#                'label': '0',
#                '_id': '81e0351260b6daab12ff2314061cbeb8',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it offers little beyond the momentary joys of pretty and weightless intellectual entertainment . ',
#                'label': '0',
#                '_id': 'dee9b4bf02ca4fa849b0b2c2fd557765',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a synthesis of cliches and absurdities that seems positively decadent in its cinematic flash and emptiness . ',
#                'label': '0',
#                '_id': '1c4db1f89a3b584ae533cfa317d0479d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a subtle and well-crafted ( for the most part ) chiller . ',
#                'label': '1',
#                '_id': 'a26fb6e14c1b73b5d43f47afda4fd9f6',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'has a lot of the virtues of eastwood at his best . ',
#                'label': '1',
#                '_id': 'bfb0a24a987da30550b1d48424070a0e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's hampered by a lifetime-channel kind of plot and a lead actress who is out of her depth . ",
#                'label': '0',
#                '_id': '832a53d178a67e537d6e551fb0c00018',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it feels like an after-school special gussied up with some fancy special effects , and watching its rote plot points connect is about as exciting as gazing at an egg timer for 93 minutes . ',
#                'label': '0',
#                '_id': 'eefd97dd68869571c7472d6af94580cb',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "for the most part , director anne-sophie birot 's first feature is a sensitive , extraordinarily well-acted drama . ",
#                'label': '1',
#                '_id': '7bda7c5756e7043ef00ea25b0a0b2cc7',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'mr. tsai is a very original artist in his medium , and what time is it there ? ',
#                'label': '1',
#                '_id': '769dcb06500c978240549103fd7ef55e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'sade is an engaging look at the controversial eponymous and fiercely atheistic hero . ',
#                'label': '1',
#                '_id': '2c0c84a1ddd61f93e8fe92a9c8ae8d60',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'so devoid of any kind of intelligible story that it makes films like xxx and collateral damage seem like thoughtful treatises ',
#                'label': '0',
#                '_id': 'fc5d89eff8d4716e70da03b0bea049ff',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a tender , heartfelt family drama . ',
#                'label': '1',
#                '_id': '37db2a297793059967134799629dbbab',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': '... a hollow joke told by a cinematic gymnast having too much fun embellishing the misanthropic tale to actually engage it . ',
#                'label': '0',
#                '_id': '070d812381d16ed96fd2a312b6fa25f5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the cold turkey would 've been a far better title . ",
#                'label': '0',
#                '_id': '4d4501cc39f823eb926c5da1c35a8bd7',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'manages to be both repulsively sadistic and mundane . ',
#                'label': '0',
#                '_id': '6239bb3f161b0ff801f0cbce652aa6b0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's just disappointingly superficial -- a movie that has all the elements necessary to be a fascinating , involving character study , but never does more than scratch the surface . ",
#                'label': '0',
#                '_id': '0fe0b8bd49fec5f46a2535988b0e4515',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "this is a story of two misfits who do n't stand a chance alone , but together they are magnificent . ",
#                'label': '1',
#                '_id': '31db54ba03c12aa2861b743bb5b66281',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'schaeffer has to find some hook on which to hang his persistently useless movies , and it might as well be the resuscitation of the middle-aged character . ',
#                'label': '0',
#                '_id': '7a9637637502b2642d8e624c50af8bd1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the primitive force of this film seems to bubble up from the vast collective memory of the combatants . ',
#                'label': '1',
#                '_id': '414cda3b044d0a1931acc5b9098728d4',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'on this tricky topic , tadpole is very much a step in the right direction , with its blend of frankness , civility and compassion . ',
#                'label': '1',
#                '_id': 'e09ddaacddb1038230935c423302d3b2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the script kicks in , and mr. hartley 's distended pace and foot-dragging rhythms follow . ",
#                'label': '0',
#                '_id': '0d0788579d57448ebf2cb7deff3b6f85',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "you wonder why enough was n't just a music video rather than a full-length movie . ",
#                'label': '0',
#                '_id': 'c412a1c48d0b34410082badeea688170',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "if you 're hard up for raunchy college humor , this is your ticket right here . ",
#                'label': '1',
#                '_id': 'e1e5a538f6e848849a3627a42802c476',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a fast , funny , highly enjoyable movie . ',
#                'label': '1',
#                '_id': '8a0ef9204dcc919cb4e01f151f85c993',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'good old-fashioned slash-and-hack is back ! ',
#                'label': '1',
#                '_id': 'e569cc5df1f0e6d513bdf5f51c5cc3f5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'this one is definitely one to skip , even for horror movie fanatics . ',
#                'label': '0',
#                '_id': '667dbfdb8dd6f899a465bd5697a2c5e0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'for all its impressive craftsmanship , and despite an overbearing series of third-act crescendos , lily chou-chou never really builds up a head of emotional steam . ',
#                'label': '0',
#                '_id': '864064d96d8848c02e8db2beee41a2f2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'exquisitely nuanced in mood tics and dialogue , this chamber drama is superbly acted by the deeply appealing veteran bouquet and the chilling but quite human berling . ',
#                'label': '1',
#                '_id': '3e36ce0466bc86fb0c8ff414e6268353',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'uses high comedy to evoke surprising poignance . ',
#                'label': '1',
#                '_id': '84dcba4a072f056ce3c42a6c9a0a5952',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'one of creepiest , scariest movies to come along in a long , long time , easily rivaling blair witch or the others . ',
#                'label': '1',
#                '_id': '148b38f60c49d8918d47e15b6ddc0aa5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a string of rehashed sight gags based in insipid vulgarity . ',
#                'label': '0',
#                '_id': '1958dfc45aa44de7e2e7d30be087e51b',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "among the year 's most intriguing explorations of alientation . ",
#                'label': '1',
#                '_id': '06038fe0bd54559e51694ece3cbd5fd2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the movie fails to live up to the sum of its parts . ',
#                'label': '0',
#                '_id': 'b9a3c05e7aa75131c70f90803276f523',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the son 's room is a triumph of gentility that earns its moments of pathos . ",
#                'label': '1',
#                '_id': '3846902d2abbeed83cfce47d99f52892',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'there is nothing outstanding about this film , but it is good enough and will likely be appreciated most by sailors and folks who know their way around a submarine . ',
#                'label': '1',
#                '_id': 'f0c80052d95df962116bca4960f2af57',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'this is a train wreck of an action film -- a stupefying attempt by the filmmakers to force-feed james bond into the mindless xxx mold and throw 40 years of cinematic history down the toilet in favor of bright flashes and loud bangs . ',
#                'label': '0',
#                '_id': 'd48b5f98d0438aa546633dd03effb951',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the draw ( for `` big bad love '' ) is a solid performance by arliss howard . ",
#                'label': '1',
#                '_id': '55e07592e90e5101ce8050fe8695a2a0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'green might want to hang onto that ski mask , as robbery may be the only way to pay for his next project . ',
#                'label': '0',
#                '_id': '71ea6fee593695e2e79aeb949892473d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's one pussy-ass world when even killer-thrillers revolve around group therapy sessions . ",
#                'label': '0',
#                '_id': '1370b4cb2d09e46dc32c99b2ed4c4aa5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "though it 's become almost redundant to say so , major kudos go to leigh for actually casting people who look working-class . ",
#                'label': '1',
#                '_id': '963d64e2426dfa78ea1b8251f50ed243',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the band 's courage in the face of official repression is inspiring , especially for aging hippies ( this one included ) . ",
#                'label': '1',
#                '_id': 'a71b11500b53071f75b11ebbe4c1feea',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the movie achieves as great an impact by keeping these thoughts hidden as ... ( quills ) did by showing them . ',
#                'label': '1',
#                '_id': '32303ceaf2f48f3cfd384ac28b2fe92a',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the film flat lines when it should peak and is more missed opportunity and trifle than dark , decadent truffle . ',
#                'label': '0',
#                '_id': 'e6badcc64558af908b9c69f304590ffe',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'jaglom ... put ( s ) the audience in the privileged position of eavesdropping on his characters ',
#                'label': '1',
#                '_id': '29a6e16efe1367629a9d2a52e41a35b1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "fresnadillo 's dark and jolting images have a way of plying into your subconscious like the nightmare you had a week ago that wo n't go away . ",
#                'label': '1',
#                '_id': '9e79eeb457403d8878cb74b1009ffe63',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "we know the plot 's a little crazy , but it held my interest from start to finish . ",
#                'label': '1',
#                '_id': 'fb8c07949a05dc46e98e0e2b1646d94f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's a scattershot affair , but when it hits its mark it 's brilliant . ",
#                'label': '1',
#                '_id': 'f8ad8b762f425e330cdffe99f236032f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'hardly a masterpiece , but it introduces viewers to a good charitable enterprise and some interesting real people . ',
#                'label': '1',
#                '_id': '78d96c5a50e03c3a09992a279c81a624',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "you wo n't like roger , but you will quickly recognize him . ",
#                'label': '0',
#                '_id': '21447e18cfdac8ecd452b7687904999e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "if steven soderbergh 's ` solaris ' is a failure it is a glorious failure . ",
#                'label': '1',
#                '_id': 'd15b7dcab382dbe199d9c2214d72ba03',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'byler reveals his characters in a way that intrigues and even fascinates us , and he never reduces the situation to simple melodrama . ',
#                'label': '1',
#                '_id': '1019aa6ad8d7a815a200bdd72a2de136',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'this riveting world war ii moral suspense story deals with the shadow side of american culture : racial prejudice in its ugly and diverse forms . ',
#                'label': '0',
#                '_id': '1b626b1e2ace23403888ef20ed84d056',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's difficult to imagine the process that produced such a script , but here 's guessing that spray cheese and underarm noises played a crucial role . ",
#                'label': '0',
#                '_id': '96426a12052b9fa376684a6e96bea904',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'no sophomore slump for director sam mendes , who segues from oscar winner to oscar-winning potential with a smooth sleight of hand . ',
#                'label': '1',
#                '_id': 'ecc26709e5edd4c62d35adce7d60cafa',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'on the whole , the movie lacks wit , feeling and believability to compensate for its incessant coarseness and banality . ',
#                'label': '0',
#                '_id': 'e41e4e3989c65dde6b853f3f10d9e117',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'why make a documentary about these marginal historical figures ? ',
#                'label': '0',
#                '_id': '7a120bf46d75385b0a6c57742b124393',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'neither parker nor donovan is a typical romantic lead , but they bring a fresh , quirky charm to the formula . ',
#                'label': '1',
#                '_id': '40aba998232b4991a78786e8b2b0dae5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'his last movie was poetically romantic and full of indelible images , but his latest has nothing going for it . ',
#                'label': '0',
#                '_id': '3a4921f99effdb518cf156b8055a4aad',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'does paint some memorable images ... , but makhmalbaf keeps her distance from the characters ',
#                'label': '1',
#                '_id': 'f1e8d7d0e4c0d287748df327afbdd436',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a gripping movie , played with performances that are all understated and touching . ',
#                'label': '1',
#                '_id': 'b7b1bf8c446c5fa0b1d7fc3375621842',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's one of those baseball pictures where the hero is stoic , the wife is patient , the kids are as cute as all get-out and the odds against success are long enough to intimidate , but short enough to make a dream seem possible . ",
#                'label': '1',
#                '_id': '378469fd00ca69c0741fb867f4a58a6a',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "combining quick-cut editing and a blaring heavy metal much of the time , beck seems to be under the illusion that he 's shooting the latest system of a down video . ",
#                'label': '0',
#                '_id': 'd34bba9332b5dabb54c8cf4b887bb20d',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the movie 's relatively simple plot and uncomplicated morality play well with the affable cast . ",
#                'label': '1',
#                '_id': '14d7b0d78c1c378c5419d4853b85d3aa',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "what the director ca n't do is make either of val kilmer 's two personas interesting or worth caring about . ",
#                'label': '0',
#                '_id': '12c4b8cfc761088a7eae2b56928991f2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "too often , the viewer is n't reacting to humor so much as they are wincing back in repugnance . ",
#                'label': '0',
#                '_id': '5c244d9cd999191aa0fd52075f288854',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's great escapist fun that recreates a place and time that will never happen again . ",
#                'label': '1',
#                '_id': '706112b3f09654ec7b3ac35c39586ada',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'scores no points for originality , wit , or intelligence . ',
#                'label': '0',
#                '_id': '73a74799c4184a7e08f7aa5c8f8fd032',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "there is n't nearly enough fun here , despite the presence of some appealing ingredients . ",
#                'label': '0',
#                '_id': 'd0e13898cbe3c0ccbf144da90c2916ff',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'hilariously inept and ridiculous . ',
#                'label': '1',
#                '_id': '8ba65c9e77fa882aba5a4598650e3d6f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'this movie is maddening . ',
#                'label': '0',
#                '_id': '96ad46c7922fad83a28a5c818620a3fd',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it haunts you , you ca n't forget it , you admire its conception and are able to resolve some of the confusions you had while watching it . ",
#                'label': '1',
#                '_id': '8268f2d6eeefbc76a95e1a5ee4ead443',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'sam mendes has become valedictorian at the school for soft landings and easy ways out . ',
#                'label': '0',
#                '_id': 'dbf2121bb054d63812619b4685eae892',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "one of the smartest takes on singles culture i 've seen in a long time . ",
#                'label': '1',
#                '_id': '512862759b540e9064902a87886ac1d9',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'moody , heartbreaking , and filmed in a natural , unforced style that makes its characters seem entirely convincing even when its script is not . ',
#                'label': '1',
#                '_id': 'ba2f06502973e03d10ba1b916c28e58f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'every nanosecond of the the new guy reminds you that you could be doing something else far more pleasurable . ',
#                'label': '0',
#                '_id': '8a3e112c9a08f0986990957404b0fb3c',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'comes ... uncomfortably close to coasting in the treads of the bicycle thief . ',
#                'label': '0',
#                '_id': '542fe74e46d4a101d045194bf2ce20e5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'warm water under a red bridge is a quirky and poignant japanese film that explores the fascinating connections between women , water , nature , and sexuality . ',
#                'label': '1',
#                '_id': '16e5b2beaf6203099bd53c81a526ae1a',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it seems to me the film is about the art of ripping people off without ever letting them consciously know you have done so ',
#                'label': '0',
#                '_id': 'bbaf22c4302fddfe28f2127bcca08f3e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'old-form moviemaking at its best . ',
#                'label': '1',
#                '_id': '09a6e34eab5ee4940f5ff441c9a9eb51',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'turns potentially forgettable formula into something strangely diverting . ',
#                'label': '1',
#                '_id': 'dba54ce98cb1e7ed86c428c767cca0da',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': '( lawrence bounces ) all over the stage , dancing , running , sweating , mopping his face and generally displaying the wacky talent that brought him fame in the first place . ',
#                'label': '1',
#                '_id': 'fc0fc3bdb361b51dda214d297414d452',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "a movie that reminds us of just how exciting and satisfying the fantasy cinema can be when it 's approached with imagination and flair . ",
#                'label': '1',
#                '_id': 'a3b17fe0255a68ca22d6cb07917d8ff1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'confirms the nagging suspicion that ethan hawke would be even worse behind the camera than he is in front of it . ',
#                'label': '0',
#                '_id': '2ca5e5afe028bf1bceef8a4853450907',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'in the end , we are left with something like two ships passing in the night rather than any insights into gay love , chinese society or the price one pays for being dishonest . ',
#                'label': '0',
#                '_id': 'f5843c8f9a08c3b9d99b2bdd6abbfc6e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'montias ... pumps a lot of energy into his nicely nuanced narrative and surrounds himself with a cast of quirky -- but not stereotyped -- street characters . ',
#                'label': '1',
#                '_id': 'e39a5a0b8917f405364db616d8220512',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it provides the grand , intelligent entertainment of a superior cast playing smart people amid a compelling plot . ',
#                'label': '1',
#                '_id': 'e6bec447e2773f636c8181dc42d788eb',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'suffers from the lack of a compelling or comprehensible narrative . ',
#                'label': '0',
#                '_id': '94a8bd52f1296dbea42ac2c40a2bd4c6',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'in execution , this clever idea is far less funny than the original , killers from space . ',
#                'label': '0',
#                '_id': 'c383d4b148811f11f55c3be7ca3bc696',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'scooby dooby doo / and shaggy too / you both look and sound great . ',
#                'label': '1',
#                '_id': 'b3f481b5473c87f15adb11178de51f1e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the tale of tok ( andy lau ) , a sleek sociopath on the trail of o ( takashi sorimachi ) , the most legendary of asian hitmen , is too scattershot to take hold . ',
#                'label': '0',
#                '_id': '830b4a376dfc368f65931c6bc9292ad2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it all drags on so interminably it 's like watching a miserable relationship unfold in real time . ",
#                'label': '0',
#                '_id': 'cf4765da94b183f21d9ae91ee1318c1f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'pumpkin means to be an outrageous dark satire on fraternity life , but its ambitions far exceed the abilities of writer adam larson broder and his co-director , tony r. abrams , in their feature debut . ',
#                'label': '0',
#                '_id': 'f860d7b5fd1a43f71e7438f0fabce434',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'looks and feels like a project better suited for the small screen . ',
#                'label': '0',
#                '_id': '4608dfed6ff3681e943f2cf43578e6b8',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'forced , familiar and thoroughly condescending . ',
#                'label': '0',
#                '_id': '8f893d4ece518c95a27e1681d1efe5f5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'that is a compliment to kuras and miller . ',
#                'label': '1',
#                '_id': '211b14437f99e2eb4317751541ffa819',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's not the ultimate depression-era gangster movie . ",
#                'label': '0',
#                '_id': '439fb568cb987485e7ff649b2c4cd8b3',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'sacrifices the value of its wealth of archival foot-age with its less-than-objective stance . ',
#                'label': '0',
#                '_id': '020a34c0289cf0881374f57dde4d68b0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the character of zigzag is not sufficiently developed to support a film constructed around him . ',
#                'label': '0',
#                '_id': '0b7cde348d21b90a082ae8190b86fc37',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "what better message than ` love thyself ' could young women of any size receive ? ",
#                'label': '1',
#                '_id': '7922d080463c4c703739f84fce2fdca3',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a solid film ... but more conscientious than it is truly stirring . ',
#                'label': '1',
#                '_id': 'be9fb2ea9071da3fc57f8d31f5c32b17',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'while ( hill ) has learned new tricks , the tricks alone are not enough to salvage this lifeless boxing film . ',
#                'label': '0',
#                '_id': '20dd90122a7972c1c0dde93c88333061',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the best that can be said about the work here of scottish director ritchie ... is that he obviously does n't have his heart in it . ",
#                'label': '0',
#                '_id': '22109df78e5509da8b170ae29d37f000',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "about a manga-like heroine who fights back at her abusers , it 's energetic and satisfying if not deep and psychological . ",
#                'label': '1',
#                '_id': 'c0fe998ae4fe0ec74b37b46448d87fa6',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the talented and clever robert rodriguez perhaps put a little too much heart into his first film and did n't reserve enough for his second . ",
#                'label': '0',
#                '_id': '2d57063cd94eabaf52940e0e98cb2fac',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'feels too formulaic and too familiar to produce the transgressive thrills of early underground work . ',
#                'label': '0',
#                '_id': 'c5bd76c31474c4eea1f2d14fda7356da',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the volatile dynamics of female friendship is the subject of this unhurried , low-key film that is so off-hollywood that it seems positively french in its rhythms and resonance . ',
#                'label': '1',
#                '_id': '0a0b9e6975de50652fdf324db32db811',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "overall very good for what it 's trying to do . ",
#                'label': '1',
#                '_id': '61eaba9eeff077e26624c07c1b770178',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a big , gorgeous , sprawling swashbuckler that delivers its diversions in grand , uncomplicated fashion . ',
#                'label': '1',
#                '_id': '45cebc08aea3df9b08bf1d707fe4eab0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a difficult , absorbing film that manages to convey more substance despite its repetitions and inconsistencies than do most films than are far more pointed and clear . ',
#                'label': '1',
#                '_id': '06840eab7d4319ea00c2d199a6968445',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the heavy-handed film is almost laughable as a consequence . ',
#                'label': '0',
#                '_id': 'e8980ee2f9b990dfaad526878ac72fd5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a solid examination of the male midlife crisis . ',
#                'label': '1',
#                '_id': '3c8bd7d712d960ce3841e6a37e359c31',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a nightmare date with a half-formed wit done a great disservice by a lack of critical distance and a sad trust in liberal arts college bumper sticker platitudes . ',
#                'label': '0',
#                '_id': 'a80afe193524d76488e260bcebccecc4',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'manages to transcend the sex , drugs and show-tunes plot into something far richer . ',
#                'label': '1',
#                '_id': 'cb60577365e523f08df5730c427f9e15',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it takes talent to make a lifeless movie about the most heinous man who ever lived . ',
#                'label': '0',
#                '_id': '2c2208c230a77657fe4b90bc9652e0a0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'by getting myself wrapped up in the visuals and eccentricities of many of the characters , i found myself confused when it came time to get to the heart of the movie . ',
#                'label': '0',
#                '_id': '9734ab37d1c6e0f99fa8cea92b0e6fc0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "like leon , it 's frustrating and still oddly likable . ",
#                'label': '1',
#                '_id': '80a0f578e4f75f76ad4bbb2541df8b17',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'uncommonly stylish but equally silly ... the picture fails to generate much suspense , nor does it ask searching enough questions to justify its pretensions . ',
#                'label': '0',
#                '_id': 'fc2c42a5ff9b32ba774410adf555229e',
# ...
#                'label': '0',
#                '_id': 'f012f528a5c380353f5ec8e53bd9a6a1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it has the charm of the original american road movies , feasting on the gorgeous , ramshackle landscape of the filmmaker 's motherland . ",
#                'label': '1',
#                '_id': '9e5dc1e4ec60d7eb373e3d28275d589b',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'exciting and direct , with ghost imagery that shows just enough to keep us on our toes . ',
#                'label': '1',
#                '_id': 'f5bb85281301c74ce589d59056830f79',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's a buggy drag . ",
#                'label': '0',
#                '_id': '92e164a7aff015e521f6099f5711bf2a',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'it wants to tweak them with a taste of tangy new humor . ',
#                'label': '1',
#                '_id': '2e056d2d6527f7db8e6f99055b7686c1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "late marriage 's stiffness is unlikely to demonstrate the emotional clout to sweep u.s. viewers off their feet . ",
#                'label': '0',
#                '_id': '2b5782e5ed225c5e321cc13cdf3cdb55',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'candid and comfortable ; a film that deftly balances action and reflection as it lets you grasp and feel the passion others have for their work . ',
#                'label': '1',
#                '_id': 'b73605c8bbbe3756748f4e362711bc09',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a quiet treasure -- a film to be savored . ',
#                'label': '1',
#                '_id': '8daab14db3cdb65771dcf1c064c15f15',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the movie , directed by mick jackson , leaves no cliche unturned , from the predictable plot to the characters straight out of central casting . ',
#                'label': '0',
#                '_id': '7b7384d95b1ca4290084cdae1de40abd',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'this is the sort of burly action flick where one coincidence pummels another , narrative necessity is a drunken roundhouse , and whatever passes for logic is a factor of the last plot device left standing . ',
#                'label': '0',
#                '_id': '1675eacd2b4deaaa3c7e2b7f5e15a19c',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'teen movies have really hit the skids . ',
#                'label': '0',
#                '_id': '95c6dfee7b0d18875569fec7bd923ae3',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "woody allen 's latest is an ambling , broad comedy about all there is to love -- and hate -- about the movie biz . ",
#                'label': '1',
#                '_id': 'bbfca04442d8ac6351b3dd93eee6404e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's made with deftly unsettling genre flair . ",
#                'label': '1',
#                '_id': 'd046695ca9056f0951c80d6ffc0ad4ac',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'manages to show life in all of its banality when the intention is quite the opposite . ',
#                'label': '0',
#                '_id': '45472c4129e21f9881cb3055059fe2cb',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'ultimately feels empty and unsatisfying , like swallowing a communion wafer without the wine . ',
#                'label': '0',
#                '_id': 'e534a92ef54ec04add62e39784fbf1b9',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'collateral damage finally delivers the goods for schwarzenegger fans . ',
#                'label': '1',
#                '_id': '4d85b41fe192746a4d1affc3ea01b5ca',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a giggle-inducing comedy with snappy dialogue and winning performances by an unlikely team of oscar-winners : susan sarandon and goldie hawn . ',
#                'label': '1',
#                '_id': '3ff547509d47b30fcc9b3af597f0f142',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's too self-important and plodding to be funny , and too clipped and abbreviated to be an epic . ",
#                'label': '0',
#                '_id': '6d9bca654e67c55eb4d14bc2e6c58a2e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'will amuse and provoke adventurous adults in specialty venues . ',
#                'label': '1',
#                '_id': '71c4d5af5a2f9b308547bedd7c1a4b35',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'sometimes seems less like storytelling than something the otherwise compelling director needed to get off his chest . ',
#                'label': '0',
#                '_id': 'da1afa0edf904467ea034e878be007ab',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'but this films lacks the passion required to sell the material . ',
#                'label': '0',
#                '_id': 'ed2ab96bbe51d53364a6d63bf5f7fe84',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'what is 100 % missing here is a script of even the most elemental literacy , an inkling of genuine wit , and anything resembling acting . ',
#                'label': '0',
#                '_id': '297df04e1d124c836c4fc01adde08502',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "there 's a wickedly subversive bent to the best parts of birthday girl . ",
#                'label': '1',
#                '_id': '69342bd7e3b29bfc2e4668476c9bddbc',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a better title , for all concerned , might be swept under the rug . ',
#                'label': '0',
#                '_id': 'e04a6bf2305157236d4c86b3ef9f9f68',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a wildly inconsistent emotional experience . ',
#                'label': '0',
#                '_id': '236510ab246b58b6b74cc443a9a3d67e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'given how heavy-handed and portent-heavy it is , this could be the worst thing soderbergh has ever done . ',
#                'label': '0',
#                '_id': '47ee2e7f4101cceb8d6ca61c368cb3d3',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'despite the evocative aesthetics evincing the hollow state of modern love life , the film never percolates beyond a monotonous whine . ',
#                'label': '0',
#                '_id': 'aad16a43a93d3d70a0a85c4ee9ef7556',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'an absurdist comedy about alienation , separation and loss . ',
#                'label': '0',
#                '_id': 'f427bd13ee398c9a374f6a9c962ff3ab',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "... mafia , rap stars and hood rats butt their ugly heads in a regurgitation of cinematic violence that gives brutal birth to an unlikely , but likable , hero . ' ",
#                'label': '1',
#                '_id': 'faaa731a36cf7ba899ba8033a0bb0432',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'his healthy sense of satire is light and fun ... ',
#                'label': '1',
#                '_id': 'edcbbe536564abb6a10200f7e787bd4f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'trademark american triteness and simplicity are tossed out the window with the intelligent french drama that deftly explores the difficult relationship between a father and son . ',
#                'label': '1',
#                '_id': 'eeddbe5afd623d0d79e6ac5fdfafffc2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'miller is playing so free with emotions , and the fact that children are hostages to fortune , that he makes the audience hostage to his swaggering affectation of seriousness . ',
#                'label': '1',
#                '_id': '6f0d35a468a19fbda67ac0a3cf8ee700',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "impostor has a handful of thrilling moments and a couple of good performances , but the movie does n't quite fly . ",
#                'label': '0',
#                '_id': 'fc5e8c3e7bbf894d966a4f11ad40b2d1',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'part low rent godfather . ',
#                'label': '0',
#                '_id': '171c93d8fd4be1288e9cce83ef2721e5',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': '( serry ) wants to blend politics and drama , an admirable ambition . ',
#                'label': '1',
#                '_id': 'c34d4a62a5ac600140ced2d3235683c0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "for all the writhing and wailing , tears , rage and opium overdoses , there 's no sense of actual passion being washed away in love 's dissolution . ",
#                'label': '0',
#                '_id': '3d6749f6879347267c35a2364efa3320',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's fascinating to see how bettany and mcdowell play off each other . ",
#                'label': '1',
#                '_id': 'c29a820e53e33c3158144095d07e9dfe',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'in a way , the film feels like a breath of fresh air , but only to those that allow it in . ',
#                'label': '1',
#                '_id': '99fdebf210f4e92eaede84963113c281',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'visually imaginative , thematically instructive and thoroughly delightful , it takes us on a roller-coaster ride from innocence to experience without even a hint of that typical kiddie-flick sentimentality . ',
#                'label': '1',
#                '_id': '51b77498c573d9c02b2fd699d3f135af',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "the film 's welcome breeziness and some unbelievably hilarious moments -- most portraying the idiocy of the film industry -- make it mostly worth the trip . ",
#                'label': '1',
#                '_id': '6bfd6ac7f5e37d2f6e35d9146612baf7',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "add yet another hat to a talented head , clooney 's a good director . ",
#                'label': '1',
#                '_id': '029a4ab954c138f225fc441d284d607e',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "stephen rea , aidan quinn , and alan bates play desmond 's legal eagles , and when joined by brosnan , the sight of this grandiloquent quartet lolling in pretty irish settings is a pleasant enough thing , ` tis . ",
#                'label': '1',
#                '_id': '6b36688a593216ece4ef5f6d00f766e6',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "bennett 's naturalistic performance speaks volumes more truth than any ` reality ' show , and anybody contemplating their own drastic life changes should watch some body first . ",
#                'label': '1',
#                '_id': '68163ff87cfbccaf99a76439ae5bf0dd',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "it 's inoffensive , cheerful , built to inspire the young people , set to an unending soundtrack of beach party pop numbers and aside from its remarkable camerawork and awesome scenery , it 's about as exciting as a sunburn . ",
#                'label': '0',
#                '_id': '50387b9037c9681c8c81fb9f0ac02f9f',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "while it 's genuinely cool to hear characters talk about early rap records ( sugar hill gang , etc. ) , the constant referencing of hip-hop arcana can alienate even the savviest audiences . ",
#                'label': '0',
#                '_id': '147b2a558a7a6b2734833f4db56f14ff',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'dull , lifeless , and amateurishly assembled . ',
#                'label': '0',
#                '_id': 'bfcdd41df38c1ba01fcfc0cb2f883abe',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "mcconaughey 's fun to watch , the dragons are okay , not much fire in the script . ",
#                'label': '1',
#                '_id': 'be94c61e6d638a6cc68fa57a4ea3afe8',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'the far future may be awesome to consider , but from period detail to matters of the heart , this film is most transporting when it stays put in the past . ',
#                'label': '1',
#                '_id': '186a86f56e6677cee80e88c89d1cae48',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'has all the depth of a wading pool . ',
#                'label': '0',
#                '_id': 'abc041da5bae0513f503130e3282a216',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a movie with a real anarchic flair . ',
#                'label': '1',
#                '_id': 'e0cb3f3d1128ad034856dbf291ce8d02',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': 'a subject like this should inspire reaction in its audience ; the pianist does not . ',
#                'label': '0',
#                '_id': '4670ae724396b055f104454e59c6ada0',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': '... is an arthritic attempt at directing by callie khouri . ',
#                'label': '0',
#                '_id': '7eb70385acd55b87322b8325c90723e2',
#                '_meta': {'added': None, 'parentId': None, 'source': None}}),
#  mappingproxy({'sentence': "looking aristocratic , luminous yet careworn in jane hamilton 's exemplary costumes , rampling gives a performance that could not be improved upon . ' ",
#                'label': '1',
#                '_id': '3e13ace95d5fe2de92f4b9683db14d36',
#                '_meta': {'added': None, 'parentId': None, 'source': None}})]
